# %% [markdown]
# <a href="https://colab.research.google.com/github/blacurly/sharing-github-oliv/blob/main/Violence_Againts_Women.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Violence Againts Women and Girls in ASEAN region**
#
# ---
#
#
#
# 1 in 3 women globally experience violence and it is belived that violence against women is a human rights priority.
#
# Personal Github --> https://github.com/blacurly/sharing-github-oliv/blob/main/Violence_Againts_Women.ipynb

# %% [markdown]
# ### **1) Import libraries**

# %%
import pandas as pd #data processing, CSV file
import numpy as np #linear algebra
import matplotlib.pyplot as plt #Data Visualization

# %% [markdown]
# ### **2) Ingest data from CSV and Define new Datasets for ASEAN region**

# %%
# Load the dataset "Violence Againts Women and Girls around the world"
violence = pd.read_csv('Violence_Against_Women.csv')
# Define a list of ASEAN Countries
asean = ['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']
# Filter the dataset to include only ASEAN countries
violence_asean = violence[violence['Country'].isin(asean)]

# %% [markdown]
# ### **3)Manage different data types**

# %%
#Convert the values in "Survey Year" into datetime objects
violence['Survey Year'] = pd.to_datetime(violence['Survey Year'])

# %% [markdown]
# ### **4) Use your function for data analysis**

# %%
#Define a function for data analysis
def analyze_data(df):
# Perform some analysis on the data
    analysis_result = df.groupby(['Country', 'Gender'])['Value'].mean()
    return analysis_result
# Use the function for data analysis
analysis_result = analyze_data(violence_asean)
analysis_result
# Out:
# Country      Gender
# Cambodia     F         27.281111
#              M         11.638889
# Indonesia    F         17.006667
#              M          8.420513
# Myanmar      F         24.211111
#              M         23.102222
# Philippines  F          5.063333
#              M               NaN
# Name: Value, dtype: float64

# %% [markdown]
# ### **5) Visualize Data to understand the common motives of violence**

# %%
from wordcloud import WordCloud #library for word cloud visualizations
from wordcloud import STOPWORDS #filtered out text data
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'maroon',
                      height =1000,
                      width = 1000
                     ).generate(str(violence_asean["Question"]))
plt.rcParams['figure.figsize'] = (10,10)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Motives of the violence againts women ")
plt.show()

# %% [markdown]
# ### **6) Data Wrangling by filtering only the case from those who has no educational background**

# %%
violence_noeducation = violence_asean[violence_asean['Demographics Response'] == 'No education']
violence_noeducation.sample(3)
# Out:
#       RecordID    Country Gender Demographics Question Demographics Response  \
# 1933       221   Cambodia      M             Education          No education
# 5814       173  Indonesia      F             Education          No education
# 1846       361   Cambodia      F             Education          No education
#
#                                      Question Survey Year  Value
# 1933         ... if she neglects the children  01/01/2014   25.0
# 5814  ... if she goes out without telling him  01/01/2012   19.8
# 1846     ... for at least one specific reason  01/01/2014   57.6

# %% [markdown]
# ### Data Source: https://www.kaggle.com/datasets/andrewmvd/violence-against-women-and-girls
#
# ### Code References:
# 1) **Author**: Gabriel Preda,
# **Code Source**: Kaggle,
# **Code Link**: https://www.kaggle.com/code/gpreda/violence-against-women-and-girls
#
# 2) **Author**: Marilia Prata,
# **Code Source**: Kaggle,
# **Code Link**: https://www.kaggle.com/code/mpwolke/violence-against-women-and-girls

# %% [markdown]
# <a href="https://colab.research.google.com/github/blacurly/sharing-github-oliv/blob/main/Homework%20I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R.version.string
# Out:
# [1] "R version 4.2.0 (2022-04-22)"

# %%
print(installed.packages())
# Out:
#               Package         LibPath                         Version
# IRdisplay     "IRdisplay"     "/usr/local/lib/R/site-library" "1.1"
# IRkernel      "IRkernel"      "/usr/local/lib/R/site-library" "1.3"
# pbdZMQ        "pbdZMQ"        "/usr/local/lib/R/site-library" "0.3-7"
# repr          "repr"          "/usr/local/lib/R/site-library" "1.1.4"
# askpass       "askpass"       "/usr/lib/R/site-library"       "1.1"
# assertthat    "assertthat"    "/usr/lib/R/site-library"       "0.2.1"
# backports     "backports"     "/usr/lib/R/site-library"       "1.4.1"
# base64enc     "base64enc"     "/usr/lib/R/site-library"       "0.1-3"
# bit           "bit"           "/usr/lib/R/site-library"       "4.0.4"
# bit64         "bit64"         "/usr/lib/R/site-library"       "4.0.5"
# blob          "blob"          "/usr/lib/R/site-library"       "1.2.3"
# brew          "brew"          "/usr/lib/R/site-library"       "1.0-7"
# ...

# %%
install.packages("googledrive")
library("googledrive")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#authorize google drive

# %%
library("readxl")

# %%
readxl(/content/wb_dev_ind.csv)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected '/'
# 1: readxl(/
#            ^
# Traceback:

# %% [markdown]
# Before analyzing the data and try to solve the study case, here is the steps need to be included:
# 1. Uploading the data that want to be analyze
# 2. Open the data to the notebook by calling the read.csv function
# 3. Summary() the data to understand the general info about the data

# %%
# read the data
wb_dev_ind = read.csv("wb_dev_ind.csv")
# summarize data
summary(wb_dev_ind)
# Out:
#  countrycode        countryname        gdp_per_capita     literacy_female
#  Length:214         Length:214         Min.   :   155.2   Min.   :  8.94
#  Class :character   Class :character   1st Qu.:  1124.4   1st Qu.: 63.40
#  Mode  :character   Mode  :character   Median :  4109.6   Median : 91.37
#                                        Mean   : 12967.2   Mean   : 78.54
#                                        3rd Qu.: 15122.3   3rd Qu.: 97.33
#                                        Max.   :158802.5   Max.   :100.00
#                                        NA's   :15         NA's   :60
#  literacy_male     literacy_all    infant_mortality
#  Min.   : 23.25   Min.   : 15.46   Min.   :  1.600
#  1st Qu.: 78.33   1st Qu.: 71.34   1st Qu.:  7.075
#  Median : 93.43   Median : 92.16   Median : 15.250
#  Mean   : 85.92   Mean   : 82.15   Mean   : 25.611
#  3rd Qu.: 98.43   3rd Qu.: 97.91   3rd Qu.: 39.650
#  Max.   :100.00   Max.   :100.00   Max.   :107.200
# ...

# %% [markdown]
# **Question 1**
# What is the mean of GDP per capita? what is the standars deviation of GDP per capita?
#
# **How to answer?**
# GDP per capita
